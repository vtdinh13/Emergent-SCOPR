# %% [markdown]
# <a href="https://colab.research.google.com/github/vtdinh13/Emergent-SCOPR/blob/main/train_doors_facade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/ultralytics -b main

# %%
# !pip install ultralytics==8.0.196

# %%
import ultralytics
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/data.yaml epochs=200 imgsz=640 plots=True project=/content/drive/MyDrive/SCOPR
# Out:
# New https://pypi.org/project/ultralytics/8.2.2 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os
from PIL import Image

# %%
image_list = [i for i in os.listdir("images")]

new_image_list = []
for i in image_list:
  new = "/content/images/" + i
  new_image_list.append(new)

new_image_list

# %%
model = YOLO("/content/drive/MyDrive/SCOPR/train/weights/best.pt")
results = model(new_image_list)
# Out:
# 0: 480x640 1 window, 1: 480x640 2 windows, 2: 480x640 1 facade, 1 window, 3: 480x640 1 window, 4: 480x640 3 windows, 5: 480x640 2 windows, 6: 480x640 1 facade, 4 windows, 7: 480x640 1 window, 8: 480x640 1 facade, 9: 480x640 1 facade, 2 windows, 10: 480x640 1 facade, 4 windows, 11: 480x640 1 facade, 12: 480x640 1 facade, 2 windows, 13: 480x640 6 windows, 14: 480x640 2 windows, 15: 480x640 1 window, 16: 480x640 (no detections), 17: 480x640 3 windows, 18: 480x640 1 facade, 2 windows, 19: 480x640 1 facade, 1 window, 20: 480x640 1 door, 1 window, 21: 480x640 1 facade, 2 windows, 22: 480x640 1 rolling-shutter, 1 window, 23: 480x640 6 windows, 24: 480x640 1 facade, 25: 480x640 1 door, 26: 480x640 1 rolling-shutter, 3 windows, 27: 480x640 1 facade, 2 windows, 28: 480x640 1 facade, 1 window, 29: 480x640 (no detections), 30: 480x640 1 facade, 3 windows, 31: 480x640 1 window, 32: 480x640 5 windows, 33: 480x640 1 facade, 4 windows, 34: 480x640 1 facade, 2 windows, 35: 480x640 1 facade, 6 windows
# ...

# %%
# Visualize the results


for image_path, result in zip(image_list, results):
    # Plot results image
    im_bgr = result.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image
    # Save results image to disk
    outpath = "/content/drive/MyDrive/SCOPR/test/"
    im_rgb.save(outpath + f'results_{image_path}')
